# %% [markdown]
# <a href="https://colab.research.google.com/github/KimberlySalazarB/Proyecto_MachineLearning/blob/main/Proyecto_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-image matplotlib numpy gdown
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gdown

# Descargar la imagen
image_url = 'https://drive.google.com/uc?id=19fhcTeMIACnUiukaqsBapSwFeiidG57J'
image_path = 'image.jpg'
gdown.download(image_url, image_path, quiet=False)

# Descargar la mascara
mask_url = 'https://drive.google.com/uc?id=1C3XJ8ThxUL4HDPOM3VViFirjNRk8HmuY'
mask_path = 'mask.jpg'
gdown.download(mask_url, mask_path, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19fhcTeMIACnUiukaqsBapSwFeiidG57J
# To: /content/image.jpg
# 100%|██████████| 19.7k/19.7k [00:00<00:00, 41.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1C3XJ8ThxUL4HDPOM3VViFirjNRk8HmuY
# To: /content/mask.jpg
# 100%|██████████| 10.7k/10.7k [00:00<00:00, 33.7MB/s]
# 'mask.jpg'

# %% [markdown]
# # **Recorte**

# %%
import skimage
from skimage import io
from skimage.measure import label, regionprops
import numpy as np
import matplotlib.pyplot as plt
import gdown

# Descarga la imagen
image_url = 'https://drive.google.com/uc?id=19fhcTeMIACnUiukaqsBapSwFeiidG57J'
image_path = 'image.jpg'
gdown.download(image_url, image_path, quiet=False)

# Descarga la máscara
mask_url = 'https://drive.google.com/uc?id=1C3XJ8ThxUL4HDPOM3VViFirjNRk8HmuY'
mask_path = 'mask.jpg'
gdown.download(mask_url, mask_path, quiet=False)

# Lee la imagen y la máscara
img = skimage.io.imread(image_path)
mask = skimage.io.imread(mask_path)

# Convierte la imagen a escala de grises
gray = skimage.color.rgb2gray(img)

# Identifica los pixeles negros en la imagen
binary = gray < 0.1  # Ajusta este valor según sea necesario para identificar el color negro

# Etiqueta las regiones de la imagen
labels = label(binary)

# Encuentra la región negra más grande
regions = regionprops(labels)
largest_region = max(regions, key=lambda region: region.area)

# Muestra la imagen original con la región negra más grande resaltada
plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.contour(labels == largest_region.label, colors='red')
plt.title('Imagen con la región negra más grande resaltada')
plt.show()

print(f"El área de la región negra más grande es {largest_region.area} píxeles.")

# Define si el recorte será vertical u horizontal
cut = "horizontal"  # Cambia a "horizontal" para un corte horizontal

# Recorta la imagen y la máscara alrededor de la región negra más grande
minr, minc, maxr, maxc = largest_region.bbox
if cut == "vertical":
    img_cropped = img[minr:maxr, :]
    mask_cropped = mask[minr:maxr, :]
else:  # cut == "horizontal"
    img_cropped = img[:, minc:maxc]
    mask_cropped = mask[:, minc:maxc]

# Muestra la imagen y la máscara recortadas
plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(img_cropped)
plt.title('Imagen Recortada')
plt.subplot(1, 2, 2)
plt.imshow(mask_cropped)
plt.title('Máscara Recortada')
plt.show()

# Guarda la imagen y la máscara recortadas
skimage.io.imsave('img_cropped.jpg', img_cropped)
skimage.io.imsave('mask_cropped.jpg', mask_cropped)

# Define las regiones sobrantes de la imagen y la máscara
if cut == "vertical":
    if minr > 0:
        img_remaining = img[:minr, :]
        mask_remaining = mask[:minr, :]
    else:
        img_remaining = img[maxr:, :]
        mask_remaining = mask[maxr:, :]
else:  # cut == "horizontal"
    if minc > 0:
        img_remaining = img[:, :minc]
        mask_remaining = mask[:, :minc]
    else:
        img_remaining = img[:, maxc:]
        mask_remaining = mask[:, maxc:]

# Verificar si las regiones sobrantes son no vacías antes de mostrar y guardar
if img_remaining.size > 0 and mask_remaining.size > 0:
    # Muestra la imagen y la máscara sobrantes
    plt.figure(figsize=(10, 10))
    plt.subplot(1, 2, 1)
    plt.imshow(img_remaining)
    plt.title('Imagen Sobrante')
    plt.subplot(1, 2, 2)
    plt.imshow(mask_remaining)
    plt.title('Máscara Sobrante')
    plt.show()

    # Guarda la imagen y la máscara sobrantes
    skimage.io.imsave('img_remaining.jpg', img_remaining)
    skimage.io.imsave('mask_remaining.jpg', mask_remaining)
else:
    print("No hay imagen/máscara sobrante después del recorte.")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19fhcTeMIACnUiukaqsBapSwFeiidG57J
# To: /content/image.jpg
# 100%|██████████| 19.7k/19.7k [00:00<00:00, 36.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1C3XJ8ThxUL4HDPOM3VViFirjNRk8HmuY
# To: /content/mask.jpg
# 100%|██████████| 10.7k/10.7k [00:00<00:00, 9.43MB/s]
# El área de la región negra más grande es 34307 píxeles.
# <ipython-input-3-ea17c912a3d4>:68: UserWarning: mask_cropped.jpg is a low contrast image
#   skimage.io.imsave('mask_cropped.jpg', mask_cropped)

# %% [markdown]
# # **Recorte para las mil imagenes**

# %%
import os
import zipfile
import skimage
from skimage import io
from skimage.measure import label, regionprops
import numpy as np
import matplotlib.pyplot as plt

# Descomprime el archivo zip
with zipfile.ZipFile('/content/segmented_images.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# Obtiene las rutas a todas las imágenes y las máscaras
img_paths = sorted(os.listdir('/content/segmented-images/images'))
mask_paths = sorted(os.listdir('/content/segmented-images/masks'))

# Procesa cada imagen y máscara
for img_path, mask_path in zip(img_paths, mask_paths):
    # Lee la imagen y la máscara
    img = skimage.io.imread('/content/segmented-images/images/' + img_path)
    mask = skimage.io.imread('/content/segmented-images/masks/' + mask_path)

    # Convierte la imagen a escala de grises
    gray = skimage.color.rgb2gray(img)

    # Identifica los pixeles negros en la imagen
    binary = gray < 0.1  # Ajusta este valor según sea necesario para identificar el color negro

    # Etiqueta las regiones de la imagen
    labels = label(binary)

    # Encuentra la región negra más grande
    regions = regionprops(labels)
    largest_region = max(regions, key=lambda region: region.area)

    # Define si el recorte será vertical u horizontal
    cut = "horizontal"  # Cambia a "horizontal" para un corte horizontal

    # Recorta la imagen y la máscara alrededor de la región negra más grande
    minr, minc, maxr, maxc = largest_region.bbox
    if cut == "vertical":
        img_cropped = img[minr:maxr, :]
        mask_cropped = mask[minr:maxr, :]
    else:  # cut == "horizontal"
        img_cropped = img[:, minc:maxc]
        mask_cropped = mask[:, minc:maxc]

    # Guarda la imagen y la máscara recortadas
    skimage.io.imsave('img_cropped.jpg', img_cropped)
    skimage.io.imsave('mask_cropped.jpg', mask_cropped)

    # Define las regiones sobrantes de la imagen y la máscara
    if cut == "vertical":
        if minr > 0:
            img_remaining = img[:minr, :]
            mask_remaining = mask[:minr, :]
        else:
            img_remaining = img[maxr:, :]
            mask_remaining = mask[maxr:, :]
    else:  # cut == "horizontal"
        if minc > 0:
            img_remaining = img[:, :minc]
            mask_remaining = mask[:, :minc]
        else:
            img_remaining = img[:, maxc:]
            mask_remaining = mask[:, maxc:]

    # Verifica si las regiones sobrantes están vacías
    if img_remaining.size != 0 and mask_remaining.size != 0:
        # Crea los directorios si no existen
        if not os.path.exists('/content/sample_data/imagen'):
            os.makedirs('/content/sample_data/imagen')
        if not os.path.exists('/content/sample_data/mascaras'):
            os.makedirs('/content/sample_data/mascaras')

        # Guarda las imágenes y las máscaras sobMis disculpas por el corte abrupto.


        # Guarda las imágenes y las máscaras sobrantes
        skimage.io.imsave('/content/sample_data/imagen/' + img_path, img_remaining)
        skimage.io.imsave('/content/sample_data/mascaras/' + mask_path, mask_remaining)
'''
import shutil

# Crea una carpeta temporal para almacenar los archivos que se van a comprimir
os.makedirs('/content/sample_data/temp', exist_ok=True)

# Mueve los archivos de imagen y máscara a la carpeta temporal
shutil.move('/content/sample_data/imagen', '/content/sample_data/temp')
shutil.move('/content/sample_data/mascaras', '/content/sample_data/temp')

# Crea un nuevo archivo ZIP
with zipfile.ZipFile('/content/sample_data/remaining_files.zip', 'w') as zipf:
    # Recorre todos los archivos en la carpeta temporal
    for foldername, subfolders, filenames in os.walk('/content/sample_data/temp'):
        for filename in filenames:
            # Crea la ruta completa del archivo
            file_path = os.path.join(foldername, filename)
            # Agrega el archivo al archivo ZIP
            zipf.write(file_path, arcname=os.path.relpath(file_path, '/content/sample_data/temp'))

# Elimina la carpeta temporal y su contenido
shutil.rmtree('/content/sample_data/temp')
'''

# %% [markdown]
# # **Escalado de imagenes**

# %%
from skimage.transform import resize

# Define una función para escalar imágenes
def scale_image(image, new_shape):
    return resize(image, new_shape)

# Define el nuevo tamaño al que quieres escalar las imágenes
new_shape = (256, 256)

# Define los directorios de entrada y salida
input_image_dir = '/content/sample_data/imagen/'
input_mask_dir = '/content/sample_data/mascaras/'
output_image_dir = '/content/sample_data/scaled_imagen/'
output_mask_dir = '/content/sample_data/scaled_mascaras/'

# Crea los directorios de salida si no existen
os.makedirs(output_image_dir, exist_ok=True)
os.makedirs(output_mask_dir, exist_ok=True)

# Obtiene las rutas a todas las imágenes y máscaras
img_paths = sorted(os.listdir(input_image_dir))
mask_paths = sorted(os.listdir(input_mask_dir))

# Procesa cada imagen y máscara
for img_path, mask_path in zip(img_paths, mask_paths):
    # Lee la imagen y la máscara
    img = skimage.io.imread(input_image_dir + img_path)
    mask = skimage.io.imread(input_mask_dir + mask_path)

    # Escala la imagen y la máscara al nuevo tamaño
    img_scaled = scale_image(img, new_shape)
    mask_scaled = scale_image(mask, new_shape)

    # Guarda la imagen y la máscara escaladas
    skimage.io.imsave(output_image_dir + img_path, img_scaled)
    skimage.io.imsave(output_mask_dir + mask_path, mask_scaled)
'''
import shutil
# Crea una carpeta temporal para almacenar los archivos que se van a comprimir
os.makedirs('/content/sample_data/temp_scaled', exist_ok=True)

# Mueve los archivos de imagen y máscara escalados a la carpeta temporal
shutil.move(output_image_dir, '/content/sample_data/temp_scaled')
shutil.move(output_mask_dir, '/content/sample_data/temp_scaled')

# Crea un nuevo archivo ZIP
with zipfile.ZipFile('/content/sample_data/scaled_files.zip', 'w') as zipf:
    # Recorre todos los archivos en la carpeta temporal
    for foldername, subfolders, filenames in os.walk('/content/sample_data/temp_scaled'):
        for filename in filenames:
            # Crea la ruta completa del archivo
            file_path = os.path.join(foldername, filename)
            # Agrega el archivo al archivo ZIP
            zipf.write(file_path, arcname=os.path.relpath(file_path, '/content/sample_data/temp_scaled'))

# Elimina la carpeta temporal y su contenido
shutil.rmtree('/content/sample_data/temp_scaled')
'''

# %%
#@title Helper

def mostrar(folder, figsize=(15, 9), grid = (4,4)):
  #https://stackoverflow.com/questions/60443761/displaying-random-images-from-multiple-folders-using-python
  images = []
  for image in os.listdir(folder):
    images.append(os.path.join(folder, image))

  plt.figure(1, figsize=figsize)
  plt.axis('off')
  n = 0
  for i in range(grid[0]*grid[1]):
    n += 1
    random_img = random.choice(images)
    imgs = imread(random_img)
    plt.subplot(*grid, n)
    plt.axis('off')
    plt.imshow(imgs)

  plt.show()

# %%
# !wget  /content/scaled_imagen.zip
# Out:
# /content/scaled_imagen.zip: Scheme missing.

# %%
# !wget  /content/scaled_imagen.zip.zip
# Out:
# /content/scaled_imagen.zip.zip: Scheme missing.

# %% [markdown]
# #COMPRIMIDO

# %%
# !unzip -qq "/content/scaled_imagen .zip"

# %%
print('scaled_imagen')
# Out:
# scaled_imagen

# %% [markdown]
# Descomprimir: Máscaras

# %%
# !unzip -qq "scaled_mascaras.zip"

# %%
print('scaled_mascaras.zip')
# Out:
# scaled_mascaras.zip

# %%
# !cd scaled_mascaras; for file in *.jpg; do mv "$file" "${file%.jpg}_mask.jpg"; done

# %% [markdown]
# #U-Net

# %%
import matplotlib.pyplot as plt
import random
import os
from skimage.io import imread
from torch.utils.data import DataLoader, random_split
from torch import optim
from os.path import splitext
from os import listdir
import numpy as np
from glob import glob
import torch
from torch.utils.data import Dataset
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function

# %%
#@title U-net

class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        # if bilinear, use the normal convolutions to reduce the number of channels
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels , in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)


    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        # if you have padding issues, see
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self, n_channels, n_classes, bilinear=True):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        self.inc = DoubleConv(n_channels, 32)
        self.down1 = Down(32, 64)
        self.down2 = Down(64, 128)
        self.down3 = Down(128, 256)
        factor = 2 if bilinear else 1
        self.down4 = Down(256, 512 // factor)
        self.up1 = Up(512, 256 // factor, bilinear)
        self.up2 = Up(256, 128 // factor, bilinear)
        self.up3 = Up(128, 64 // factor, bilinear)
        self.up4 = Up(64, 32, bilinear)
        self.outc = OutConv(32, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        return logits

# %%
#@title Dataset

class BasicDataset(Dataset):
    def __init__(self, imgs_dir, masks_dir, scale=1, mask_suffix=''):
        self.imgs_dir = imgs_dir
        self.masks_dir = masks_dir
        self.scale = scale
        self.mask_suffix = mask_suffix
        assert 0 < scale <= 1, 'Scale must be between 0 and 1'

        self.ids = [splitext(file)[0] for file in listdir(imgs_dir)
                    if not file.startswith('.')]


    def __len__(self):
        return len(self.ids)

    @classmethod
    def preprocess(cls, pil_img, scale):
        w, h = pil_img.size
        newW, newH = int(scale * w), int(scale * h)
        assert newW > 0 and newH > 0, 'Scale is too small'
        pil_img = pil_img.resize((newW, newH))

        img_nd = np.array(pil_img)

        if len(img_nd.shape) == 2:
            img_nd = np.expand_dims(img_nd, axis=2)

        # HWC to CHW
        img_trans = img_nd.transpose((2, 0, 1))
        if img_trans.max() > 1:
            img_trans = img_trans / 255

        return img_trans

    def __getitem__(self, i):
        idx = self.ids[i]
        mask_file = glob(self.masks_dir + idx + self.mask_suffix + '.*')
        img_file = glob(self.imgs_dir + idx + '.*')

        assert len(mask_file) == 1, \
            f'Either no mask or multiple masks found for the ID {idx}: {mask_file}'
        assert len(img_file) == 1, \
            f'Either no image or multiple images found for the ID {idx}: {img_file}'
        mask = Image.open(mask_file[0])
        img = Image.open(img_file[0])

        assert img.size == mask.size, \
            f'Image and mask {idx} should be the same size, but are {img.size} and {mask.size}'

        img = self.preprocess(img, self.scale)
        mask = self.preprocess(mask, self.scale)

        return {
            'image': torch.from_numpy(img).type(torch.FloatTensor),
            'mask': torch.from_numpy(mask).type(torch.FloatTensor)
        }

# %%
#@title Evaluación
def eval_net(net, loader, device):
    """Evaluation without the densecrf with the dice coefficient"""
    net.eval()
    mask_type = torch.float32 if net.n_classes == 1 else torch.long
    n_val = len(loader)  # the number of batch
    tot = 0


    for batch in loader:
      imgs, true_masks = batch['image'], batch['mask']
      imgs = imgs.to(device=device, dtype=torch.float32)
      true_masks = true_masks.to(device=device, dtype=mask_type)

      with torch.no_grad():
        mask_pred = net(imgs)

      if net.n_classes > 1:
        tot += F.cross_entropy(mask_pred, true_masks).item()
      else:
        pred = torch.sigmoid(mask_pred)
        pred = (pred > 0.5).float()
        #cambios
        tot += dice_coeff(pred, true_masks).mean().item()

    net.train()
    return tot / n_val


class DiceCoeff(Function):
    """Dice coeff for individual examples"""

    def forward(self, input, target):
        self.save_for_backward(input, target)
        eps = 0.0001
        #self.inter = torch.dot(input.view(-1), target.view(-1))
        #cambios
        self.inter = torch.matmul(input.flatten(-1), target.flatten(-1))
        self.union = torch.sum(input) + torch.sum(target) + eps

        t = (2 * self.inter.float() + eps) / self.union.float()
        return t

    # This function has only a single output, so it gets only one gradient
    def backward(self, grad_output):

        input, target = self.saved_variables
        grad_input = grad_target = None

        if self.needs_input_grad[0]:
            grad_input = grad_output * 2 * (target * self.union - self.inter) \
                         / (self.union * self.union)
        if self.needs_input_grad[1]:
            grad_target = None

        return grad_input, grad_target


def dice_coeff(input, target):
    """Dice coeff for batches"""
    if input.is_cuda:
        s = torch.FloatTensor(1).cuda().zero_()
    else:
        s = torch.FloatTensor(1).zero_()

    for i, c in enumerate(zip(input, target)):
        s = s + DiceCoeff().forward(c[0], c[1])

    return s / (i + 1)

# %% [markdown]
# ### **Entrenamiento**

# %%
#@title Parámetros
img_scale = 1.0
val_percent = 0.3
batch_size = 64
num_workers = 2
lr = 0.0001
epochs = 100
dir_img = 'scaled_imagen/'
dir_mask = 'scaled_mascaras/'
device = torch.device('cuda')
criterion = nn.BCEWithLogitsLoss() #si es multiclase, usar nn.CrossEntropyLoss()

# %%
dataset = BasicDataset(dir_img, dir_mask, img_scale, mask_suffix='_mask')
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train, val = random_split(dataset, [n_train, n_val])
train_loade = DataLoader(train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
val_loader = DataLoader(val, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True, drop_last=True)
net = UNet(n_channels=3, n_classes=1, bilinear=True)
net.to(device=device)
optimizer = optim.RMSprop(net.parameters(), lr=lr, weight_decay=1e-8, momentum=0.9)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min' if net.n_classes > 1 else 'max', patience=2)
global_step = 0

# %%
lista_train=[]
lista_val=[]

# %%
for epoch in range(epochs):
  net.train()
  epoch_loss = 0
  for batch in train_loade:
    imgs = batch['image']
    imgs = imgs.to(device=device, dtype=torch.float32)
    mask_type = torch.float32 if net.n_classes == 1 else torch.long
    true_masks = batch['mask'][:,0:1]
    true_masks = true_masks.to(device=device, dtype=mask_type)
    masks_pred = net(imgs)
    loss = criterion(masks_pred, true_masks)
    epoch_loss += loss.item()
    optimizer.zero_grad()
    loss.backward()
    nn.utils.clip_grad_value_(net.parameters(), 0.1)
    optimizer.step()
    global_step += 1
    if global_step % 10 == 0:
      print("Iter {}".format(global_step))
  val_score = eval_net(net, val_loader, device)
  scheduler.step(val_score)
  print("Train Loss {}".format(epoch_loss))
  lista_train.append(np.mean(epoch_loss))
  print("Val Score {}".format(val_score))
  lista_val.append(np.mean(val_score))
# Out:
# Iter 10
# Train Loss 6.308555364608765
# Val Score 0.0007593145564896986
# Iter 20
# Train Loss 5.085869610309601
# Val Score 0.0005002645120839588
# Iter 30
# Train Loss 4.5540288388729095
# Val Score 0.0005419521767180413
# Iter 40
# Train Loss 4.30352458357811
# Val Score 0.008248310172348283
# Iter 50
# Train Loss 4.116953045129776
# Val Score 0.004430103290360421
# Iter 60
# Train Loss 3.9726532995700836
# Val Score 0.004337757745815907
# Iter 70
# Train Loss 3.774625062942505
# Val Score 0.00437435440835543
# Iter 80
# Train Loss 3.707529067993164
# Val Score 0.004177969014563132
# Iter 90
# Train Loss 3.610388606786728
# Val Score 0.004152095109020593
# Iter 100
# Iter 110
# Train Loss 3.5379745066165924
# Val Score 0.004133855196414515
# Iter 120
# Train Loss 3.520077884197235
# Val Score 0.00417468132218346
# Iter 130
# Train Loss 3.5077169239521027
# Val Score 0.004184908466413617
# Iter 140
# Train Loss 3.4850447475910187
# Val Score 0.004188432511000428
# Iter 150
# Train Loss 3.4670808613300323
# Val Score 0.004188740502286237
# Iter 160
# Train Loss 3.4877710938453674
# Val Score 0.004186977792414837
# Iter 170
# Train Loss 3.4888802468776703
# Val Score 0.004187566846667323
# Iter 180
# Train Loss 3.4862000346183777
# Val Score 0.004190729574474972
# Iter 190
# Train Loss 3.473017692565918
# Val Score 0.004187741855275817
# Iter 200
# Train Loss 3.4828392565250397
# Val Score 0.0041891318032867275
# Iter 210
# Iter 220
# Train Loss 3.479033946990967
# Val Score 0.004191218708001543
# Iter 230
# Train Loss 3.4699290096759796
# Val Score 0.004188922815956175
# Iter 240
# Train Loss 3.472126752138138
# Val Score 0.004187862170510925
# Iter 250
# Train Loss 3.4669047594070435
# Val Score 0.0041926569465431385
# Iter 260
# Train Loss 3.4943093359470367
# Val Score 0.004190545238088816
# Iter 270
# Train Loss 3.4851953983306885
# Val Score 0.004188960563624278
# Iter 280
# Train Loss 3.4740197956562042
# Val Score 0.004189980863884557
# Iter 290
# Train Loss 3.4738749563694
# Val Score 0.0041903354722307995
# Iter 300
# Train Loss 3.4864633977413177
# Val Score 0.0041893056986737065
# Iter 310
# Train Loss 3.4790149927139282
# Val Score 0.004187445025308989
# Iter 320
# Iter 330
# Train Loss 3.480565160512924
# Val Score 0.004186444311926607
# Iter 340
# Train Loss 3.4651478230953217
# Val Score 0.004187881866528187
# Iter 350
# Train Loss 3.4757958352565765
# Val Score 0.004190653293335345
# Iter 360
# Train Loss 3.4770054817199707
# Val Score 0.004188014296232723
# Iter 370
# Train Loss 3.4710321128368378
# Val Score 0.0041896074180840515
# Iter 380
# Train Loss 3.488170862197876
# Val Score 0.00419095202232711
# Iter 390
# Train Loss 3.488456606864929
# Val Score 0.0041902649027178995
# Iter 400
# Train Loss 3.479339361190796
# Val Score 0.004186980608210433
# Iter 410
# Train Loss 3.4584785401821136
# Val Score 0.004192243097350001
# Iter 420
# Train Loss 3.489225059747696
# Val Score 0.004191671119770035
# Iter 430
# Iter 440
# Train Loss 3.4876601099967957
# Val Score 0.004191360050754156
# Iter 450
# Train Loss 3.4759799242019653
# Val Score 0.00418670864746673
# Iter 460
# Train Loss 3.4746619164943695
# Val Score 0.0041898740018950775
# Iter 470
# Train Loss 3.4879107773303986
# Val Score 0.004192439133476
# Iter 480
# Train Loss 3.487875908613205
# Val Score 0.004190292434941512
# Iter 490
# Train Loss 3.4849471151828766
# Val Score 0.004191840569546912
# Iter 500
# Train Loss 3.4835041165351868
# Val Score 0.0041916417321772315
# Iter 510
# Train Loss 3.498761236667633
# Val Score 0.004190441017271951
# Iter 520
# Train Loss 3.4770286679267883
# Val Score 0.00419266023527598
# Iter 530
# Train Loss 3.4857248961925507
# Val Score 0.004189211336779408
# Iter 540
# Iter 550
# Train Loss 3.482986271381378
# Val Score 0.004188489416264929
# Iter 560
# Train Loss 3.4765246212482452
# Val Score 0.004190049352473579
# Iter 570
# Train Loss 3.4820021092891693
# Val Score 0.004190422572719399
# Iter 580
# Train Loss 3.4780368506908417
# Val Score 0.004193939166725613
# Iter 590
# Train Loss 3.488162010908127
# Val Score 0.004188267281278968
# Iter 600
# Train Loss 3.494394302368164
# Val Score 0.004188336199149489
# Iter 610
# Train Loss 3.4626816511154175
# Val Score 0.004187102225841954
# Iter 620
# Train Loss 3.4600276350975037
# Val Score 0.004189951112493873
# Iter 630
# Train Loss 3.494979500770569
# Val Score 0.004188975719443988
# Iter 640
# Train Loss 3.4812110662460327
# Val Score 0.004188217884802725
# Iter 650
# Iter 660
# Train Loss 3.4745588302612305
# Val Score 0.00419206826336449
# Iter 670
# Train Loss 3.485430955886841
# Val Score 0.004191660322248936
# Iter 680
# Train Loss 3.478447198867798
# Val Score 0.0041892758454196155
# Iter 690
# Train Loss 3.481381505727768
# Val Score 0.004189083359960932
# Iter 700
# Train Loss 3.4582268595695496
# Val Score 0.00418877718038857
# Iter 710
# Train Loss 3.4670075178146362
# Val Score 0.004188702179817483
# Iter 720
# Train Loss 3.4807137846946716
# Val Score 0.004192465377855115
# Iter 730
# Train Loss 3.4809755086898804
# Val Score 0.004190440900856629
# Iter 740
# Train Loss 3.4867000579833984
# Val Score 0.0041879179334500805
# Iter 750
# Train Loss 3.479642301797867
# Val Score 0.004192283900920302
# Iter 760
# Iter 770
# Train Loss 3.4878030121326447
# Val Score 0.004188765000435524
# Iter 780
# Train Loss 3.484371066093445
# Val Score 0.004193251093965955
# Iter 790
# Train Loss 3.48061802983284
# Val Score 0.004193068314634729
# Iter 800
# Train Loss 3.479881912469864
# Val Score 0.004190643412584905
# Iter 810
# Train Loss 3.4894739985466003
# Val Score 0.004190523286524694
# Iter 820
# Train Loss 3.4776908457279205
# Val Score 0.004190346924588084
# Iter 830
# Train Loss 3.475229561328888
# Val Score 0.00418724944756832
# Iter 840
# Train Loss 3.47344970703125
# Val Score 0.004188600636553019
# Iter 850
# Train Loss 3.4712032079696655
# Val Score 0.004188550708931871
# Iter 860
# Train Loss 3.4738566279411316
# Val Score 0.00419040146516636
# Iter 870
# Iter 880
# Train Loss 3.4760736227035522
# Val Score 0.0041907363120117225
# Iter 890
# Train Loss 3.477108985185623
# Val Score 0.004189983003016096
# Iter 900
# Train Loss 3.5040977001190186
# Val Score 0.004191634099697694
# Iter 910
# Train Loss 3.4845149517059326
# Val Score 0.004192177941149566
# Iter 920
# Train Loss 3.4791902005672455
# Val Score 0.004191424130112864
# Iter 930
# Train Loss 3.484925150871277
# Val Score 0.004190551393548958
# Iter 940
# Train Loss 3.494498759508133
# Val Score 0.004190720741462428
# Iter 950
# Train Loss 3.467603474855423
# Val Score 0.004189545463304967
# Iter 960
# Train Loss 3.5005750358104706
# Val Score 0.0041874860908137634
# Iter 970
# Train Loss 3.4799031019210815
# Val Score 0.004189616010989994
# Iter 980
# Iter 990
# Train Loss 3.479227840900421
# Val Score 0.004190028688753955
# Iter 1000
# Train Loss 3.499665677547455
# Val Score 0.00419033919024514
# Iter 1010
# Train Loss 3.46793857216835
# Val Score 0.004190079082036391
# Iter 1020
# Train Loss 3.483895719051361
# Val Score 0.004189384140772745
# Iter 1030
# Train Loss 3.468073606491089
# Val Score 0.004191844993329141
# Iter 1040
# Train Loss 3.4851091504096985
# Val Score 0.004190303807263263
# Iter 1050
# Train Loss 3.4813112318515778
# Val Score 0.0041893774177879095
# Iter 1060
# Train Loss 3.4928483963012695
# Val Score 0.0041894070818671025
# Iter 1070
# Train Loss 3.4863861203193665
# Val Score 0.004188544015050866
# Iter 1080
# Train Loss 3.4730903804302216
# Val Score 0.004192457548924722
# Iter 1090
# Iter 1100
# Train Loss 3.47606161236763
# Val Score 0.004190682935586665

# %% [markdown]
# **Graficas**

# %% [markdown]
# **Curva de entrenamineto**

# %% [markdown]
# **Metricas**

# %%
import pandas as pd

# %%
s=pd.Series(lista_train).plot()
s.plot(xlabel='Eje X', ylabel='Eje Y')
# Out:
# []

# %%
pd.Series(lista_val).plot()
# Out:
# <Axes: >

# %%
print(n_val, "ejemplos de validación")
# Out:
# 294 ejemplos de validación

# %% [markdown]
# **th=umbral**

# %%
# Definir una lista de valores de umbral para probar
thresholds = [-2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5, 2]

# Crear una lista para almacenar el coeficiente de Sørensen-Dice promedio para cada valor de umbral
sorensen_dice_coefficients = []

# Recorrer todos los valores de umbral
for th in thresholds:
    # Crear una lista para almacenar el coeficiente de Sørensen-Dice para cada imagen en el conjunto de validación
    sorensen_dice_coefficients_per_image = []

    # Recorrer todas las imágenes en el conjunto de datos de validación
    for i in range(n_val):
        # Obtener la imagen y la máscara verdadera
        im = val[i]['image']
        mask_to_show = val[i]['mask'][0]

        # Obtener la máscara predicha
        net.eval()
        with torch.no_grad():
            predicted_mask = net(im.unsqueeze(0).to(device)).cpu().numpy()[0, 0]

        # Convertir las máscaras predicha y verdadera en matrices binarias utilizando el valor de umbral actual
        predicted_mask_binary = (predicted_mask > th).astype(int)
        mask_to_show_binary = mask_to_show.numpy().astype(int)

        # Calcular la intersección y la unión de las dos máscaras
        intersection = np.logical_and(predicted_mask_binary, mask_to_show_binary)
        union = np.logical_or(predicted_mask_binary, mask_to_show_binary)

        # Calcular el coeficiente de Sørensen-Dice para esta imagen
        sorensen_dice_coefficient = 2 * intersection.sum() / (predicted_mask_binary.sum() + mask_to_show_binary.sum() + 1e-6)


        # Agregar el coeficiente de Sørensen-Dice a la lista
        sorensen_dice_coefficients_per_image.append(sorensen_dice_coefficient)

    # Calcular el coeficiente de Sørensen-Dice promedio para este valor de umbral
    mean_sorensen_dice_coefficient = np.mean(sorensen_dice_coefficients_per_image)

    # Agregar el coeficiente de Sørensen-Dice promedio a la lista
    sorensen_dice_coefficients.append(mean_sorensen_dice_coefficient)

# Encontrar el índice del valor de umbral que maximiza el coeficiente de Sørensen-Dice promedio
best_threshold_index = np.argmax(sorensen_dice_coefficients)

# Obtener el mejor valor de umbral
best_threshold = thresholds[best_threshold_index]

# Imprimir el resultado
print(f'El mejor valor de umbral es: {best_threshold}')
# Out:
# El mejor valor de umbral es: -1

# %%
#@title Evaluación { run: "auto" }
i = 172 #@param {type:"slider", min:0, max:254, step:1}
th = -0.5 #@param {type:"slider", min:-15, max:15, step:0.5}
im = val[i]['image']
im_to_show = im.numpy().transpose((1,2,0))
mask_to_show = val[i]['mask'][0]
plt.figure(figsize=(20,8))
plt.subplot(1,4,  1)
plt.axis('off')
plt.imshow(im_to_show)
plt.subplot(1,4,  2)
net.eval()
with torch.no_grad():
  predicted_mask = net(im.unsqueeze(0).to(device)).cpu().numpy()[0, 0]
plt.subplot(1,4,  2)
plt.imshow(predicted_mask)
plt.axis('off')
plt.title('Predicted Mask')
plt.subplot(1,4,  3)
plt.imshow(predicted_mask>th)
plt.axis('off')
plt.title('Predicted Mask Binary')

plt.subplot(1,4,  4)
plt.imshow(mask_to_show)
plt.axis('off')
plt.title('True Mask')

      # Convertir las máscaras predicha y verdadera en matrices binarias
predicted_mask_binary = (predicted_mask > th).astype(int)
mask_to_show_binary = mask_to_show.numpy().astype(int)

      # Calcular la intersección y la unión de las dos máscaras
intersection = np.logical_and(predicted_mask_binary, mask_to_show_binary)

      # Calcular el coeficiente de Sørensen-Dice para esta imagen
sorensen_dice_coefficient = 2 * intersection.sum() / (predicted_mask_binary.sum() + mask_to_show_binary.sum())

plt.figure(figsize=(5,5))
plt.imshow(intersection)
plt.axis('off')
plt.title(f'Dice: {sorensen_dice_coefficient:.4f}')
plt.show()

# %% [markdown]
# **Diff Coef**

# %% [markdown]
# **Este codigo es para visualizar el Dice de cada imagen**

# %%
# Establecer el valor del umbral
th = -0.5

# Recorrer todas las imágenes en el conjunto de datos de validación
for i in range(len(val)):
    im = val[i]['image']
    im_to_show = im.numpy().transpose((1,2,0))
    mask_to_show = val[i]['mask'][0]
    plt.figure(figsize=(20,8))

    plt.subplot(1,4,  1)
    plt.axis('off')
    plt.imshow(im_to_show)
    plt.title('Image')

    net.eval()
    with torch.no_grad():
        predicted_mask = net(im.unsqueeze(0).to(device)).cpu().numpy()[0, 0]

    plt.subplot(1,4,  2)
    plt.imshow(predicted_mask)
    plt.axis('off')
    plt.title('Predicted Mask')

    plt.subplot(1,4,  3)
    plt.imshow(predicted_mask>th)
    plt.axis('off')
    plt.title('Predicted Mask Binary')

    plt.subplot(1,4,  4)
    plt.imshow(mask_to_show)
    plt.axis('off')
    plt.title('True Mask')

    # Convertir las máscaras predicha y verdadera en matrices binarias
    predicted_mask_binary = (predicted_mask > th).astype(int)
    mask_to_show_binary = mask_to_show.numpy().astype(int)

    # Calcular la intersección y la unión de las dos máscaras
    intersection = np.logical_and(predicted_mask_binary, mask_to_show_binary)

    # Calcular el coeficiente de Sørensen-Dice para esta imagen
    sorensen_dice_coefficient = 2 * intersection.sum() / (predicted_mask_binary.sum() + mask_to_show_binary.sum())

    plt.figure(figsize=(5,5))
    plt.imshow(intersection)
    plt.axis('off')
    plt.title(f'Dice: {sorensen_dice_coefficient:.4f}')

    plt.show()

# %%
# Establecer el valor del umbral
th = -0.5

# Crear una lista vacía para almacenar los valores del coeficiente de Sørensen-Dice
sorensen_dice_coefficients = []

# Recorrer todas las imágenes en el conjunto de datos de validación desde la imagen 0 hasta la imagen 249
for i in range(n_val):
    # Obtener la imagen y la máscara verdadera
    im = val[i]['image']
    mask_to_show = val[i]['mask'][0]

    # Obtener la máscara predicha
    net.eval()
    with torch.no_grad():
        predicted_mask = net(im.unsqueeze(0).to(device)).cpu().numpy()[0, 0]

    # Convertir las máscaras predicha y verdadera en matrices binarias
    predicted_mask_binary = (predicted_mask > th).astype(int)
    mask_to_show_binary = mask_to_show.numpy().astype(int)

    # Calcular la intersección y la unión de las dos máscaras
    intersection = np.logical_and(predicted_mask_binary, mask_to_show_binary)
    union = np.logical_or(predicted_mask_binary, mask_to_show_binary)

    # Calcular el coeficiente de Sørensen-Dice para esta imagen
    sorensen_dice_coefficient = 2 * intersection.sum() / (predicted_mask_binary.sum() + mask_to_show_binary.sum())

    # Agregar el valor a la lista
    sorensen_dice_coefficients.append(sorensen_dice_coefficient)

    # Imprimir el resultado
    print(f'Coeficiente de Sørensen-Dice para la imagen {i}: {sorensen_dice_coefficient:.4f}')
# Out:
# Coeficiente de Sørensen-Dice para la imagen 0: 0.7412
# Coeficiente de Sørensen-Dice para la imagen 1: 0.4792
# Coeficiente de Sørensen-Dice para la imagen 2: 0.7213
# Coeficiente de Sørensen-Dice para la imagen 3: 0.5814
# Coeficiente de Sørensen-Dice para la imagen 4: 0.5199
# Coeficiente de Sørensen-Dice para la imagen 5: 0.1278
# Coeficiente de Sørensen-Dice para la imagen 6: 0.6139
# Coeficiente de Sørensen-Dice para la imagen 7: 0.1407
# Coeficiente de Sørensen-Dice para la imagen 8: 0.3842
# Coeficiente de Sørensen-Dice para la imagen 9: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 10: 0.6339
# Coeficiente de Sørensen-Dice para la imagen 11: 0.3015
# Coeficiente de Sørensen-Dice para la imagen 12: 0.1707
# Coeficiente de Sørensen-Dice para la imagen 13: 0.6307
# Coeficiente de Sørensen-Dice para la imagen 14: 0.8155
# Coeficiente de Sørensen-Dice para la imagen 15: 0.0899
# Coeficiente de Sørensen-Dice para la imagen 16: 0.0869
# Coeficiente de Sørensen-Dice para la imagen 17: 0.8305
# Coeficiente de Sørensen-Dice para la imagen 18: 0.4881
# Coeficiente de Sørensen-Dice para la imagen 19: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 20: 0.8948
# Coeficiente de Sørensen-Dice para la imagen 21: 0.6543
# Coeficiente de Sørensen-Dice para la imagen 22: 0.3243
# Coeficiente de Sørensen-Dice para la imagen 23: 0.5185
# Coeficiente de Sørensen-Dice para la imagen 24: 0.5652
# Coeficiente de Sørensen-Dice para la imagen 25: 0.7947
# Coeficiente de Sørensen-Dice para la imagen 26: 0.3885
# Coeficiente de Sørensen-Dice para la imagen 27: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 28: 0.8047
# Coeficiente de Sørensen-Dice para la imagen 29: 0.7173
# Coeficiente de Sørensen-Dice para la imagen 30: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 31: 0.8559
# Coeficiente de Sørensen-Dice para la imagen 32: 0.8103
# Coeficiente de Sørensen-Dice para la imagen 33: 0.6611
# Coeficiente de Sørensen-Dice para la imagen 34: 0.7855
# Coeficiente de Sørensen-Dice para la imagen 35: 0.0254
# Coeficiente de Sørensen-Dice para la imagen 36: 0.1559
# Coeficiente de Sørensen-Dice para la imagen 37: 0.4269
# Coeficiente de Sørensen-Dice para la imagen 38: 0.8075
# Coeficiente de Sørensen-Dice para la imagen 39: 0.2023
# Coeficiente de Sørensen-Dice para la imagen 40: 0.5008
# Coeficiente de Sørensen-Dice para la imagen 41: 0.8242
# Coeficiente de Sørensen-Dice para la imagen 42: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 43: 0.9077
# Coeficiente de Sørensen-Dice para la imagen 44: 0.8054
# Coeficiente de Sørensen-Dice para la imagen 45: 0.3579
# Coeficiente de Sørensen-Dice para la imagen 46: 0.7984
# Coeficiente de Sørensen-Dice para la imagen 47: 0.6898
# Coeficiente de Sørensen-Dice para la imagen 48: 0.8493
# Coeficiente de Sørensen-Dice para la imagen 49: 0.0014
# Coeficiente de Sørensen-Dice para la imagen 50: 0.8642
# Coeficiente de Sørensen-Dice para la imagen 51: 0.8872
# Coeficiente de Sørensen-Dice para la imagen 52: 0.4582
# Coeficiente de Sørensen-Dice para la imagen 53: 0.4147
# Coeficiente de Sørensen-Dice para la imagen 54: 0.2201
# Coeficiente de Sørensen-Dice para la imagen 55: 0.4631
# Coeficiente de Sørensen-Dice para la imagen 56: 0.9156
# Coeficiente de Sørensen-Dice para la imagen 57: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 58: 0.5948
# Coeficiente de Sørensen-Dice para la imagen 59: 0.3560
# Coeficiente de Sørensen-Dice para la imagen 60: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 61: 0.4073
# Coeficiente de Sørensen-Dice para la imagen 62: 0.4967
# Coeficiente de Sørensen-Dice para la imagen 63: 0.5012
# Coeficiente de Sørensen-Dice para la imagen 64: 0.8443
# Coeficiente de Sørensen-Dice para la imagen 65: 0.8795
# Coeficiente de Sørensen-Dice para la imagen 66: 0.2130
# Coeficiente de Sørensen-Dice para la imagen 67: 0.2597
# Coeficiente de Sørensen-Dice para la imagen 68: 0.7582
# Coeficiente de Sørensen-Dice para la imagen 69: 0.3949
# Coeficiente de Sørensen-Dice para la imagen 70: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 71: 0.6918
# Coeficiente de Sørensen-Dice para la imagen 72: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 73: 0.4705
# Coeficiente de Sørensen-Dice para la imagen 74: 0.8555
# Coeficiente de Sørensen-Dice para la imagen 75: nan
# Coeficiente de Sørensen-Dice para la imagen 76: 0.6799
# Coeficiente de Sørensen-Dice para la imagen 77: 0.4367
# Coeficiente de Sørensen-Dice para la imagen 78: 0.7719
# Coeficiente de Sørensen-Dice para la imagen 79: 0.5123
# Coeficiente de Sørensen-Dice para la imagen 80: 0.0000
# <ipython-input-37-ff30c7fda83f>:27: RuntimeWarning: invalid value encountered in long_scalars
#   sorensen_dice_coefficient = 2 * intersection.sum() / (predicted_mask_binary.sum() + mask_to_show_binary.sum())
# Coeficiente de Sørensen-Dice para la imagen 81: 0.8035
# Coeficiente de Sørensen-Dice para la imagen 82: 0.5854
# Coeficiente de Sørensen-Dice para la imagen 83: 0.7260
# Coeficiente de Sørensen-Dice para la imagen 84: 0.2201
# Coeficiente de Sørensen-Dice para la imagen 85: 0.2582
# Coeficiente de Sørensen-Dice para la imagen 86: 0.2610
# Coeficiente de Sørensen-Dice para la imagen 87: 0.1774
# Coeficiente de Sørensen-Dice para la imagen 88: 0.4662
# Coeficiente de Sørensen-Dice para la imagen 89: 0.7377
# Coeficiente de Sørensen-Dice para la imagen 90: 0.2124
# Coeficiente de Sørensen-Dice para la imagen 91: 0.6703
# Coeficiente de Sørensen-Dice para la imagen 92: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 93: 0.3926
# Coeficiente de Sørensen-Dice para la imagen 94: 0.5938
# Coeficiente de Sørensen-Dice para la imagen 95: 0.8314
# Coeficiente de Sørensen-Dice para la imagen 96: 0.9165
# Coeficiente de Sørensen-Dice para la imagen 97: 0.7709
# Coeficiente de Sørensen-Dice para la imagen 98: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 99: 0.5426
# Coeficiente de Sørensen-Dice para la imagen 100: 0.3596
# Coeficiente de Sørensen-Dice para la imagen 101: 0.8171
# Coeficiente de Sørensen-Dice para la imagen 102: 0.5811
# Coeficiente de Sørensen-Dice para la imagen 103: 0.6832
# Coeficiente de Sørensen-Dice para la imagen 104: 0.0001
# Coeficiente de Sørensen-Dice para la imagen 105: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 106: 0.6837
# Coeficiente de Sørensen-Dice para la imagen 107: 0.3290
# Coeficiente de Sørensen-Dice para la imagen 108: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 109: 0.4248
# Coeficiente de Sørensen-Dice para la imagen 110: 0.3151
# Coeficiente de Sørensen-Dice para la imagen 111: 0.1215
# Coeficiente de Sørensen-Dice para la imagen 112: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 113: 0.5426
# Coeficiente de Sørensen-Dice para la imagen 114: 0.6159
# Coeficiente de Sørensen-Dice para la imagen 115: 0.8412
# Coeficiente de Sørensen-Dice para la imagen 116: 0.5436
# Coeficiente de Sørensen-Dice para la imagen 117: 0.8599
# Coeficiente de Sørensen-Dice para la imagen 118: 0.4449
# Coeficiente de Sørensen-Dice para la imagen 119: 0.5688
# Coeficiente de Sørensen-Dice para la imagen 120: 0.6765
# Coeficiente de Sørensen-Dice para la imagen 121: 0.2274
# Coeficiente de Sørensen-Dice para la imagen 122: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 123: 0.8390
# Coeficiente de Sørensen-Dice para la imagen 124: 0.8349
# Coeficiente de Sørensen-Dice para la imagen 125: 0.1111
# Coeficiente de Sørensen-Dice para la imagen 126: 0.6259
# Coeficiente de Sørensen-Dice para la imagen 127: 0.7963
# Coeficiente de Sørensen-Dice para la imagen 128: 0.4520
# Coeficiente de Sørensen-Dice para la imagen 129: 0.4869
# Coeficiente de Sørensen-Dice para la imagen 130: 0.5283
# Coeficiente de Sørensen-Dice para la imagen 131: 0.2742
# Coeficiente de Sørensen-Dice para la imagen 132: 0.7268
# Coeficiente de Sørensen-Dice para la imagen 133: 0.6991
# Coeficiente de Sørensen-Dice para la imagen 134: 0.8872
# Coeficiente de Sørensen-Dice para la imagen 135: 0.2722
# Coeficiente de Sørensen-Dice para la imagen 136: 0.8945
# Coeficiente de Sørensen-Dice para la imagen 137: 0.6642
# Coeficiente de Sørensen-Dice para la imagen 138: 0.4559
# Coeficiente de Sørensen-Dice para la imagen 139: 0.8133
# Coeficiente de Sørensen-Dice para la imagen 140: 0.0802
# Coeficiente de Sørensen-Dice para la imagen 141: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 142: 0.4948
# Coeficiente de Sørensen-Dice para la imagen 143: 0.3407
# Coeficiente de Sørensen-Dice para la imagen 144: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 145: 0.8495
# Coeficiente de Sørensen-Dice para la imagen 146: 0.5487
# Coeficiente de Sørensen-Dice para la imagen 147: 0.5903
# Coeficiente de Sørensen-Dice para la imagen 148: 0.8477
# Coeficiente de Sørensen-Dice para la imagen 149: 0.0015
# Coeficiente de Sørensen-Dice para la imagen 150: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 151: 0.4987
# Coeficiente de Sørensen-Dice para la imagen 152: 0.9054
# Coeficiente de Sørensen-Dice para la imagen 153: 0.7464
# Coeficiente de Sørensen-Dice para la imagen 154: 0.8630
# Coeficiente de Sørensen-Dice para la imagen 155: 0.5506
# Coeficiente de Sørensen-Dice para la imagen 156: 0.5070
# Coeficiente de Sørensen-Dice para la imagen 157: 0.7108
# Coeficiente de Sørensen-Dice para la imagen 158: 0.0163
# Coeficiente de Sørensen-Dice para la imagen 159: 0.4669
# Coeficiente de Sørensen-Dice para la imagen 160: 0.8905
# Coeficiente de Sørensen-Dice para la imagen 161: 0.5822
# Coeficiente de Sørensen-Dice para la imagen 162: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 163: 0.2471
# Coeficiente de Sørensen-Dice para la imagen 164: 0.1619
# Coeficiente de Sørensen-Dice para la imagen 165: 0.8496
# Coeficiente de Sørensen-Dice para la imagen 166: 0.1171
# Coeficiente de Sørensen-Dice para la imagen 167: 0.7294
# Coeficiente de Sørensen-Dice para la imagen 168: 0.8254
# Coeficiente de Sørensen-Dice para la imagen 169: 0.4841
# Coeficiente de Sørensen-Dice para la imagen 170: 0.8342
# Coeficiente de Sørensen-Dice para la imagen 171: 0.3169
# Coeficiente de Sørensen-Dice para la imagen 172: 0.7900
# Coeficiente de Sørensen-Dice para la imagen 173: 0.5567
# Coeficiente de Sørensen-Dice para la imagen 174: 0.4011
# Coeficiente de Sørensen-Dice para la imagen 175: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 176: 0.3995
# Coeficiente de Sørensen-Dice para la imagen 177: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 178: 0.8132
# Coeficiente de Sørensen-Dice para la imagen 179: 0.4822
# Coeficiente de Sørensen-Dice para la imagen 180: 0.8309
# Coeficiente de Sørensen-Dice para la imagen 181: 0.5938
# Coeficiente de Sørensen-Dice para la imagen 182: 0.0358
# Coeficiente de Sørensen-Dice para la imagen 183: 0.4833
# Coeficiente de Sørensen-Dice para la imagen 184: 0.5578
# Coeficiente de Sørensen-Dice para la imagen 185: 0.7212
# Coeficiente de Sørensen-Dice para la imagen 186: 0.5374
# Coeficiente de Sørensen-Dice para la imagen 187: 0.4837
# Coeficiente de Sørensen-Dice para la imagen 188: 0.7289
# Coeficiente de Sørensen-Dice para la imagen 189: 0.6089
# Coeficiente de Sørensen-Dice para la imagen 190: 0.6660
# Coeficiente de Sørensen-Dice para la imagen 191: 0.7300
# Coeficiente de Sørensen-Dice para la imagen 192: 0.5516
# Coeficiente de Sørensen-Dice para la imagen 193: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 194: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 195: 0.8658
# Coeficiente de Sørensen-Dice para la imagen 196: 0.8672
# Coeficiente de Sørensen-Dice para la imagen 197: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 198: 0.8301
# Coeficiente de Sørensen-Dice para la imagen 199: 0.3010
# Coeficiente de Sørensen-Dice para la imagen 200: 0.4770
# Coeficiente de Sørensen-Dice para la imagen 201: 0.7591
# Coeficiente de Sørensen-Dice para la imagen 202: 0.0145
# Coeficiente de Sørensen-Dice para la imagen 203: 0.5346
# Coeficiente de Sørensen-Dice para la imagen 204: 0.3257
# Coeficiente de Sørensen-Dice para la imagen 205: 0.8734
# Coeficiente de Sørensen-Dice para la imagen 206: 0.0484
# Coeficiente de Sørensen-Dice para la imagen 207: 0.8696
# Coeficiente de Sørensen-Dice para la imagen 208: 0.2372
# Coeficiente de Sørensen-Dice para la imagen 209: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 210: 0.3358
# Coeficiente de Sørensen-Dice para la imagen 211: 0.6945
# Coeficiente de Sørensen-Dice para la imagen 212: 0.7325
# Coeficiente de Sørensen-Dice para la imagen 213: 0.0224
# Coeficiente de Sørensen-Dice para la imagen 214: 0.8411
# Coeficiente de Sørensen-Dice para la imagen 215: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 216: 0.6075
# Coeficiente de Sørensen-Dice para la imagen 217: 0.5619
# Coeficiente de Sørensen-Dice para la imagen 218: 0.2550
# Coeficiente de Sørensen-Dice para la imagen 219: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 220: 0.8724
# Coeficiente de Sørensen-Dice para la imagen 221: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 222: 0.9279
# Coeficiente de Sørensen-Dice para la imagen 223: 0.7093
# Coeficiente de Sørensen-Dice para la imagen 224: 0.7387
# Coeficiente de Sørensen-Dice para la imagen 225: 0.2914
# Coeficiente de Sørensen-Dice para la imagen 226: 0.6331
# Coeficiente de Sørensen-Dice para la imagen 227: 0.0309
# Coeficiente de Sørensen-Dice para la imagen 228: 0.7786
# Coeficiente de Sørensen-Dice para la imagen 229: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 230: 0.3906
# Coeficiente de Sørensen-Dice para la imagen 231: 0.3640
# Coeficiente de Sørensen-Dice para la imagen 232: 0.9045
# Coeficiente de Sørensen-Dice para la imagen 233: 0.8110
# Coeficiente de Sørensen-Dice para la imagen 234: 0.8201
# Coeficiente de Sørensen-Dice para la imagen 235: 0.8000
# Coeficiente de Sørensen-Dice para la imagen 236: 0.6269
# Coeficiente de Sørensen-Dice para la imagen 237: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 238: 0.2408
# Coeficiente de Sørensen-Dice para la imagen 239: 0.0727
# Coeficiente de Sørensen-Dice para la imagen 240: 0.7811
# Coeficiente de Sørensen-Dice para la imagen 241: 0.5865
# Coeficiente de Sørensen-Dice para la imagen 242: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 243: 0.7258
# Coeficiente de Sørensen-Dice para la imagen 244: 0.4485
# Coeficiente de Sørensen-Dice para la imagen 245: 0.8682
# Coeficiente de Sørensen-Dice para la imagen 246: 0.7041
# Coeficiente de Sørensen-Dice para la imagen 247: 0.7045
# Coeficiente de Sørensen-Dice para la imagen 248: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 249: 0.0853
# Coeficiente de Sørensen-Dice para la imagen 250: 0.5213
# Coeficiente de Sørensen-Dice para la imagen 251: 0.5691
# Coeficiente de Sørensen-Dice para la imagen 252: 0.1282
# Coeficiente de Sørensen-Dice para la imagen 253: 0.7574
# Coeficiente de Sørensen-Dice para la imagen 254: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 255: 0.3315
# Coeficiente de Sørensen-Dice para la imagen 256: 0.0002
# Coeficiente de Sørensen-Dice para la imagen 257: 0.5484
# Coeficiente de Sørensen-Dice para la imagen 258: 0.0007
# Coeficiente de Sørensen-Dice para la imagen 259: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 260: 0.5463
# Coeficiente de Sørensen-Dice para la imagen 261: 0.8864
# Coeficiente de Sørensen-Dice para la imagen 262: 0.7847
# Coeficiente de Sørensen-Dice para la imagen 263: 0.4254
# Coeficiente de Sørensen-Dice para la imagen 264: 0.4762
# Coeficiente de Sørensen-Dice para la imagen 265: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 266: 0.6981
# Coeficiente de Sørensen-Dice para la imagen 267: 0.7138
# Coeficiente de Sørensen-Dice para la imagen 268: 0.6650
# Coeficiente de Sørensen-Dice para la imagen 269: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 270: 0.7030
# Coeficiente de Sørensen-Dice para la imagen 271: 0.6313
# Coeficiente de Sørensen-Dice para la imagen 272: 0.6200
# Coeficiente de Sørensen-Dice para la imagen 273: 0.8167
# Coeficiente de Sørensen-Dice para la imagen 274: 0.5252
# Coeficiente de Sørensen-Dice para la imagen 275: 0.8517
# Coeficiente de Sørensen-Dice para la imagen 276: 0.6591
# Coeficiente de Sørensen-Dice para la imagen 277: 0.5045
# Coeficiente de Sørensen-Dice para la imagen 278: 0.5510
# Coeficiente de Sørensen-Dice para la imagen 279: 0.8761
# Coeficiente de Sørensen-Dice para la imagen 280: 0.4743
# Coeficiente de Sørensen-Dice para la imagen 281: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 282: 0.8973
# Coeficiente de Sørensen-Dice para la imagen 283: 0.8301
# Coeficiente de Sørensen-Dice para la imagen 284: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 285: 0.6285
# Coeficiente de Sørensen-Dice para la imagen 286: 0.5386
# Coeficiente de Sørensen-Dice para la imagen 287: 0.7993
# Coeficiente de Sørensen-Dice para la imagen 288: 0.1085
# Coeficiente de Sørensen-Dice para la imagen 289: 0.6003
# Coeficiente de Sørensen-Dice para la imagen 290: 0.0000
# Coeficiente de Sørensen-Dice para la imagen 291: 0.0043
# Coeficiente de Sørensen-Dice para la imagen 292: 0.8778
# Coeficiente de Sørensen-Dice para la imagen 293: 0.0027

# %%
print(sorensen_dice_coefficients)
# Out:
# [0.7412208343153429, 0.4792381539885106, 0.7213138318898911, 0.5813500784929356, 0.5198653691373382, 0.12783919597989948, 0.6138892967258845, 0.14070577657900651, 0.38419800802735243, 0.0, 0.6339126559714795, 0.3014887114265996, 0.17069397770309916, 0.6306938926360528, 0.8155497722836695, 0.08992269089922691, 0.08693171010081796, 0.8305489260143198, 0.4881088280060883, 0.0, 0.8948407846972746, 0.6543284134548651, 0.32427944490570515, 0.5185469079361603, 0.5652212207510056, 0.7946874527016801, 0.3885118357887767, 0.0, 0.8046568102278409, 0.7172733138497742, 0.0, 0.8558790546995058, 0.8102629078238834, 0.6611053180396246, 0.7854996243425996, 0.025371908369079127, 0.15587899543378994, 0.42690582959641254, 0.8074551185418665, 0.20228747012632298, 0.5007999534572534, 0.8242432728885155, 0.0, 0.9077251387110542, 0.8054437416139544, 0.357860004713646, 0.7983819919408377, 0.6898395721925134, 0.8492940976356523, 0.0014139271827500884, 0.8641914481787788, 0.8871695680206318, 0.458245466048081, 0.4146865806743607, 0.22006872852233678, 0.4631069385360129, 0.9155860349127182, 0.0, 0.5948094724288716, 0.35601287339649157, 0.0, 0.4073139974779319, 0.4966712898751734, 0.5012139605462822, 0.8442950199621769, 0.8794882084936616, 0.21298420839519502, 0.2597327135386403, 0.7581533248623464, 0.39493705280318814, 0.0, 0.6917894950108899, 0.0, 0.47048413601314626, 0.8555288210063814, nan, 0.6799189904969621, 0.43668067490434676, 0.771920139847272, 0.5122646098255854, 0.0, 0.80349461851689, 0.5853510282646135, 0.7260109707870902, 0.22006610512847852, 0.25815395840933963, 0.26101413133832085, 0.17736909635241646, 0.46619160728424386, 0.7376674937965261, 0.21244167962674962, 0.6702705624780387, 0.0, 0.39260969976905313, 0.5938166030785423, 0.8314257167790158, 0.9165295085821773, 0.7708842208109429, 0.0, 0.5426281941053066, 0.35963505113294564, 0.8171415286854545, 0.5811021731300277, 0.6832038254632397, 8.499426288725512e-05, 0.0, 0.6837155141526334, 0.32897196261682243, 0.0, 0.4247951769979904, 0.3151108983564704, 0.12149129120483662, 0.0, 0.5425882134742894, 0.6158695922684475, 0.8411904812994871, 0.5435649059078755, 0.8598784543056989, 0.4449333668594418, 0.5688188188188188, 0.6764716484625645, 0.22742969906265417, 0.0, 0.8390401425310394, 0.8348594884748973, 0.1111111111111111, 0.625945945945946, 0.7962784728905999, 0.45196728162875394, 0.48691202519189136, 0.528328255583196, 0.2741662518666003, 0.7268095572733662, 0.6990974094478959, 0.8871746012232228, 0.27216817622721684, 0.8944617216965527, 0.6641619613989137, 0.4559166389113575, 0.8133039323778023, 0.08020110126885324, 0.0, 0.49482124958235885, 0.34073647871116225, 0.0, 0.8495221794323207, 0.5487374806037523, 0.5902573991783349, 0.8477251105266104, 0.0015082956259426848, 0.0, 0.498733221928737, 0.9054158220801096, 0.7464234397451115, 0.8630201536900102, 0.5506321772416193, 0.5070209066999509, 0.710835545489985, 0.016322492889823174, 0.46689539382436673, 0.8904590753144911, 0.5821673979634076, 0.0, 0.24711902808703465, 0.16188996625060267, 0.8496348808698897, 0.11710350955131053, 0.729414662178803, 0.8253740344025501, 0.48413952998208454, 0.8341917543223311, 0.31688471602277973, 0.7899875851424353, 0.5566801619433198, 0.4010906009358535, 0.0, 0.39952675646159447, 0.0, 0.8131760078662733, 0.4821787754445249, 0.8308562314217357, 0.59375, 0.03575615474794842, 0.4832657200811359, 0.5578333083944337, 0.7212347604778129, 0.5374097849345374, 0.4836932569413839, 0.7288549482750966, 0.6088526343942231, 0.6660462952192625, 0.7299776841061245, 0.5515688335084822, 0.0, 0.0, 0.8658076811534159, 0.8671949549848567, 0.0, 0.8301314459049545, 0.3009890403635392, 0.4769740942977535, 0.7591046367027892, 0.014474845542806708, 0.5346422369493568, 0.32569667738478025, 0.873385908657596, 0.04842105263157895, 0.8696120689655172, 0.23717756126872397, 0.0, 0.33578143360752055, 0.6944790134630614, 0.7324519558402617, 0.022366545224140662, 0.8410563723782315, 0.0, 0.6074678800856531, 0.5619254958877601, 0.25502414706340554 ...

# %%
import pandas as pd
sorensen_dice_coefficients_series = pd.Series(sorensen_dice_coefficients)
sorensen_dice_coefficients_summary = sorensen_dice_coefficients_series.describe()
print(sorensen_dice_coefficients_summary)
# Out:
# count    293.000000
# mean       0.479690
# std        0.305887
# min        0.000000
# 25%        0.220066
# 50%        0.537410
# 75%        0.741221
# max        0.927932
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crea un DataFrame de Pandas con tus datos
df = pd.DataFrame(sorensen_dice_coefficients, columns=['Coeficiente de Dice'])

# Crea un diagrama de caja y bigotes usando el método boxplot de Pandas
df.boxplot(column=['Coeficiente de Dice'])

# Muestra el gráfico
plt.show()

# %% [markdown]
# **IOU**

# %%
#@title Evaluación { run: "auto" }
i = 172 #@param {type:"slider", min:0, max:254, step:1}
th = -0.5 #@param {type:"slider", min:-15, max:15, step:0.5}
im = val[i]['image']
im_to_show = im.numpy().transpose((1,2,0))
mask_to_show = val[i]['mask'][0]
plt.figure(figsize=(20,8))
plt.subplot(1,4,  1)
plt.axis('off')
plt.imshow(im_to_show)
plt.subplot(1,4,  2)
net.eval()
with torch.no_grad():
  predicted_mask = net(im.unsqueeze(0).to(device)).cpu().numpy()[0, 0]
plt.subplot(1,4,  2)
plt.imshow(predicted_mask)
plt.axis('off')
plt.title('Predicted Mask')

plt.subplot(1,4,  3)
plt.imshow(predicted_mask>th)
plt.axis('off')
plt.title('Predicted Mask Binary')

plt.subplot(1,4,  4)
plt.imshow(mask_to_show)
plt.axis('off')
plt.title('True Mask')

    # Convertir las máscaras predicha y verdadera en matrices binarias
predicted_mask_binary = (predicted_mask > th).astype(int)
mask_to_show_binary = mask_to_show.numpy().astype(int)

    # Calcular la intersección y la unión de las dos máscaras
intersection = np.logical_and(predicted_mask_binary, mask_to_show_binary)
union = np.logical_or(predicted_mask_binary, mask_to_show_binary)

    # Calcular el coeficiente de Jaccard (IoU) para esta imagen
jaccard_coefficient = intersection.sum() / union.sum()

plt.figure(figsize=(5,5))
plt.imshow(intersection)
plt.axis('off')
plt.title(f'IoU: {jaccard_coefficient:.4f}')
# Out:
# Text(0.5, 1.0, 'IoU: 0.6529')

# %% [markdown]
# ** seccion de Codigo para visualizar las imagenes con el valor de Iou**

# %%
# Establecer el valor del umbral
th = -0.5

# Recorrer todas las imágenes en el conjunto de datos de validación
for i in range(len(val)):
    im = val[i]['image']
    im_to_show = im.numpy().transpose((1,2,0))
    mask_to_show = val[i]['mask'][0]
    plt.figure(figsize=(20,8))

    plt.subplot(1,4,  1)
    plt.axis('off')
    plt.imshow(im_to_show)
    plt.title('Image')

    net.eval()
    with torch.no_grad():
        predicted_mask = net(im.unsqueeze(0).to(device)).cpu().numpy()[0, 0]

    plt.subplot(1,4,  2)
    plt.imshow(predicted_mask)
    plt.axis('off')
    plt.title('Predicted Mask')

    plt.subplot(1,4,  3)
    plt.imshow(predicted_mask>th)
    plt.axis('off')
    plt.title('Predicted Mask Binary')

    plt.subplot(1,4,  4)
    plt.imshow(mask_to_show)
    plt.axis('off')
    plt.title('True Mask')

    # Convertir las máscaras predicha y verdadera en matrices binarias
    predicted_mask_binary = (predicted_mask > th).astype(int)
    mask_to_show_binary = mask_to_show.numpy().astype(int)

    # Calcular la intersección y la unión de las dos máscaras
    intersection = np.logical_and(predicted_mask_binary, mask_to_show_binary)
    union = np.logical_or(predicted_mask_binary, mask_to_show_binary)

    # Calcular el coeficiente de Jaccard (IoU) para esta imagen
    jaccard_coefficient = intersection.sum() / union.sum()

    plt.figure(figsize=(5,5))
    plt.imshow(intersection)
    plt.axis('off')
    plt.title(f'IoU: {jaccard_coefficient:.4f}')

    plt.show()

# %%
# Establecer el valor del umbral
th = -0.5
jaccard_coefficients= []
# Recorrer todas las imágenes en el conjunto de datos de validación
for i in range(len(val)):
    im = val[i]['image']
    mask_to_show = val[i]['mask'][0]

    net.eval()
    with torch.no_grad():
        predicted_mask = net(im.unsqueeze(0).to(device)).cpu().numpy()[0, 0]

    # Convertir las máscaras predicha y verdadera en matrices binarias
    predicted_mask_binary = (predicted_mask > th).astype(int)
    mask_to_show_binary = mask_to_show.numpy().astype(int)

    # Calcular la intersección y la unión de las dos máscaras
    intersection = np.logical_and(predicted_mask_binary, mask_to_show_binary)
    union = np.logical_or(predicted_mask_binary, mask_to_show_binary)

    # Calcular el coeficiente de Jaccard (IoU) para esta imagen
    jaccard_coefficient = intersection.sum() / union.sum()
    jaccard_coefficients.append(jaccard_coefficient)
    # Imprimir el resultado
    print(f'Coeficiente de Jaccard (IoU) para la imagen {i}: {jaccard_coefficient:.4f}')
# Out:
# Coeficiente de Jaccard (IoU) para la imagen 0: 0.5888
# Coeficiente de Jaccard (IoU) para la imagen 1: 0.3151
# Coeficiente de Jaccard (IoU) para la imagen 2: 0.5641
# Coeficiente de Jaccard (IoU) para la imagen 3: 0.4098
# Coeficiente de Jaccard (IoU) para la imagen 4: 0.3512
# Coeficiente de Jaccard (IoU) para la imagen 5: 0.0683
# Coeficiente de Jaccard (IoU) para la imagen 6: 0.4429
# Coeficiente de Jaccard (IoU) para la imagen 7: 0.0757
# Coeficiente de Jaccard (IoU) para la imagen 8: 0.2378
# Coeficiente de Jaccard (IoU) para la imagen 9: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 10: 0.4640
# Coeficiente de Jaccard (IoU) para la imagen 11: 0.1775
# Coeficiente de Jaccard (IoU) para la imagen 12: 0.0933
# Coeficiente de Jaccard (IoU) para la imagen 13: 0.4606
# Coeficiente de Jaccard (IoU) para la imagen 14: 0.6885
# Coeficiente de Jaccard (IoU) para la imagen 15: 0.0471
# Coeficiente de Jaccard (IoU) para la imagen 16: 0.0454
# Coeficiente de Jaccard (IoU) para la imagen 17: 0.7102
# Coeficiente de Jaccard (IoU) para la imagen 18: 0.3228
# Coeficiente de Jaccard (IoU) para la imagen 19: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 20: 0.8097
# Coeficiente de Jaccard (IoU) para la imagen 21: 0.4862
# Coeficiente de Jaccard (IoU) para la imagen 22: 0.1935
# Coeficiente de Jaccard (IoU) para la imagen 23: 0.3500
# Coeficiente de Jaccard (IoU) para la imagen 24: 0.3939
# Coeficiente de Jaccard (IoU) para la imagen 25: 0.6593
# Coeficiente de Jaccard (IoU) para la imagen 26: 0.2411
# Coeficiente de Jaccard (IoU) para la imagen 27: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 28: 0.6732
# Coeficiente de Jaccard (IoU) para la imagen 29: 0.5592
# Coeficiente de Jaccard (IoU) para la imagen 30: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 31: 0.7481
# Coeficiente de Jaccard (IoU) para la imagen 32: 0.6810
# Coeficiente de Jaccard (IoU) para la imagen 33: 0.4938
# Coeficiente de Jaccard (IoU) para la imagen 34: 0.6468
# Coeficiente de Jaccard (IoU) para la imagen 35: 0.0128
# Coeficiente de Jaccard (IoU) para la imagen 36: 0.0845
# Coeficiente de Jaccard (IoU) para la imagen 37: 0.2714
# Coeficiente de Jaccard (IoU) para la imagen 38: 0.6771
# Coeficiente de Jaccard (IoU) para la imagen 39: 0.1125
# Coeficiente de Jaccard (IoU) para la imagen 40: 0.3340
# Coeficiente de Jaccard (IoU) para la imagen 41: 0.7010
# Coeficiente de Jaccard (IoU) para la imagen 42: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 43: 0.8310
# Coeficiente de Jaccard (IoU) para la imagen 44: 0.6743
# Coeficiente de Jaccard (IoU) para la imagen 45: 0.2179
# Coeficiente de Jaccard (IoU) para la imagen 46: 0.6644
# Coeficiente de Jaccard (IoU) para la imagen 47: 0.5265
# Coeficiente de Jaccard (IoU) para la imagen 48: 0.7381
# Coeficiente de Jaccard (IoU) para la imagen 49: 0.0007
# Coeficiente de Jaccard (IoU) para la imagen 50: 0.7609
# Coeficiente de Jaccard (IoU) para la imagen 51: 0.7972
# Coeficiente de Jaccard (IoU) para la imagen 52: 0.2972
# Coeficiente de Jaccard (IoU) para la imagen 53: 0.2616
# Coeficiente de Jaccard (IoU) para la imagen 54: 0.1236
# Coeficiente de Jaccard (IoU) para la imagen 55: 0.3013
# Coeficiente de Jaccard (IoU) para la imagen 56: 0.8443
# Coeficiente de Jaccard (IoU) para la imagen 57: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 58: 0.4233
# Coeficiente de Jaccard (IoU) para la imagen 59: 0.2166
# Coeficiente de Jaccard (IoU) para la imagen 60: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 61: 0.2557
# Coeficiente de Jaccard (IoU) para la imagen 62: 0.3304
# Coeficiente de Jaccard (IoU) para la imagen 63: 0.3344
# Coeficiente de Jaccard (IoU) para la imagen 64: 0.7305
# Coeficiente de Jaccard (IoU) para la imagen 65: 0.7849
# Coeficiente de Jaccard (IoU) para la imagen 66: 0.1192
# Coeficiente de Jaccard (IoU) para la imagen 67: 0.1492
# Coeficiente de Jaccard (IoU) para la imagen 68: 0.6105
# Coeficiente de Jaccard (IoU) para la imagen 69: 0.2461
# Coeficiente de Jaccard (IoU) para la imagen 70: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 71: 0.5288
# Coeficiente de Jaccard (IoU) para la imagen 72: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 73: 0.3076
# Coeficiente de Jaccard (IoU) para la imagen 74: 0.7475
# Coeficiente de Jaccard (IoU) para la imagen 75: nan
# Coeficiente de Jaccard (IoU) para la imagen 76: 0.5151
# Coeficiente de Jaccard (IoU) para la imagen 77: 0.2793
# Coeficiente de Jaccard (IoU) para la imagen 78: 0.6286
# Coeficiente de Jaccard (IoU) para la imagen 79: 0.3443
# Coeficiente de Jaccard (IoU) para la imagen 80: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 81: 0.6715
# <ipython-input-44-f74008638215>:22: RuntimeWarning: invalid value encountered in long_scalars
#   jaccard_coefficient = intersection.sum() / union.sum()
# Coeficiente de Jaccard (IoU) para la imagen 82: 0.4138
# Coeficiente de Jaccard (IoU) para la imagen 83: 0.5699
# Coeficiente de Jaccard (IoU) para la imagen 84: 0.1236
# Coeficiente de Jaccard (IoU) para la imagen 85: 0.1482
# Coeficiente de Jaccard (IoU) para la imagen 86: 0.1501
# Coeficiente de Jaccard (IoU) para la imagen 87: 0.0973
# Coeficiente de Jaccard (IoU) para la imagen 88: 0.3039
# Coeficiente de Jaccard (IoU) para la imagen 89: 0.5844
# Coeficiente de Jaccard (IoU) para la imagen 90: 0.1188
# Coeficiente de Jaccard (IoU) para la imagen 91: 0.5041
# Coeficiente de Jaccard (IoU) para la imagen 92: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 93: 0.2443
# Coeficiente de Jaccard (IoU) para la imagen 94: 0.4223
# Coeficiente de Jaccard (IoU) para la imagen 95: 0.7115
# Coeficiente de Jaccard (IoU) para la imagen 96: 0.8459
# Coeficiente de Jaccard (IoU) para la imagen 97: 0.6272
# Coeficiente de Jaccard (IoU) para la imagen 98: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 99: 0.3723
# Coeficiente de Jaccard (IoU) para la imagen 100: 0.2192
# Coeficiente de Jaccard (IoU) para la imagen 101: 0.6908
# Coeficiente de Jaccard (IoU) para la imagen 102: 0.4095
# Coeficiente de Jaccard (IoU) para la imagen 103: 0.5188
# Coeficiente de Jaccard (IoU) para la imagen 104: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 105: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 106: 0.5194
# Coeficiente de Jaccard (IoU) para la imagen 107: 0.1969
# Coeficiente de Jaccard (IoU) para la imagen 108: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 109: 0.2697
# Coeficiente de Jaccard (IoU) para la imagen 110: 0.1870
# Coeficiente de Jaccard (IoU) para la imagen 111: 0.0647
# Coeficiente de Jaccard (IoU) para la imagen 112: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 113: 0.3723
# Coeficiente de Jaccard (IoU) para la imagen 114: 0.4450
# Coeficiente de Jaccard (IoU) para la imagen 115: 0.7259
# Coeficiente de Jaccard (IoU) para la imagen 116: 0.3732
# Coeficiente de Jaccard (IoU) para la imagen 117: 0.7542
# Coeficiente de Jaccard (IoU) para la imagen 118: 0.2861
# Coeficiente de Jaccard (IoU) para la imagen 119: 0.3974
# Coeficiente de Jaccard (IoU) para la imagen 120: 0.5111
# Coeficiente de Jaccard (IoU) para la imagen 121: 0.1283
# Coeficiente de Jaccard (IoU) para la imagen 122: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 123: 0.7227
# Coeficiente de Jaccard (IoU) para la imagen 124: 0.7165
# Coeficiente de Jaccard (IoU) para la imagen 125: 0.0588
# Coeficiente de Jaccard (IoU) para la imagen 126: 0.4555
# Coeficiente de Jaccard (IoU) para la imagen 127: 0.6615
# Coeficiente de Jaccard (IoU) para la imagen 128: 0.2920
# Coeficiente de Jaccard (IoU) para la imagen 129: 0.3218
# Coeficiente de Jaccard (IoU) para la imagen 130: 0.3590
# Coeficiente de Jaccard (IoU) para la imagen 131: 0.1589
# Coeficiente de Jaccard (IoU) para la imagen 132: 0.5709
# Coeficiente de Jaccard (IoU) para la imagen 133: 0.5374
# Coeficiente de Jaccard (IoU) para la imagen 134: 0.7972
# Coeficiente de Jaccard (IoU) para la imagen 135: 0.1575
# Coeficiente de Jaccard (IoU) para la imagen 136: 0.8091
# Coeficiente de Jaccard (IoU) para la imagen 137: 0.4972
# Coeficiente de Jaccard (IoU) para la imagen 138: 0.2953
# Coeficiente de Jaccard (IoU) para la imagen 139: 0.6854
# Coeficiente de Jaccard (IoU) para la imagen 140: 0.0418
# Coeficiente de Jaccard (IoU) para la imagen 141: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 142: 0.3287
# Coeficiente de Jaccard (IoU) para la imagen 143: 0.2054
# Coeficiente de Jaccard (IoU) para la imagen 144: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 145: 0.7384
# Coeficiente de Jaccard (IoU) para la imagen 146: 0.3781
# Coeficiente de Jaccard (IoU) para la imagen 147: 0.4187
# Coeficiente de Jaccard (IoU) para la imagen 148: 0.7357
# Coeficiente de Jaccard (IoU) para la imagen 149: 0.0008
# Coeficiente de Jaccard (IoU) para la imagen 150: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 151: 0.3322
# Coeficiente de Jaccard (IoU) para la imagen 152: 0.8272
# Coeficiente de Jaccard (IoU) para la imagen 153: 0.5954
# Coeficiente de Jaccard (IoU) para la imagen 154: 0.7590
# Coeficiente de Jaccard (IoU) para la imagen 155: 0.3799
# Coeficiente de Jaccard (IoU) para la imagen 156: 0.3396
# Coeficiente de Jaccard (IoU) para la imagen 157: 0.5514
# Coeficiente de Jaccard (IoU) para la imagen 158: 0.0082
# Coeficiente de Jaccard (IoU) para la imagen 159: 0.3045
# Coeficiente de Jaccard (IoU) para la imagen 160: 0.8025
# Coeficiente de Jaccard (IoU) para la imagen 161: 0.4106
# Coeficiente de Jaccard (IoU) para la imagen 162: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 163: 0.1410
# Coeficiente de Jaccard (IoU) para la imagen 164: 0.0881
# Coeficiente de Jaccard (IoU) para la imagen 165: 0.7386
# Coeficiente de Jaccard (IoU) para la imagen 166: 0.0622
# Coeficiente de Jaccard (IoU) para la imagen 167: 0.5741
# Coeficiente de Jaccard (IoU) para la imagen 168: 0.7027
# Coeficiente de Jaccard (IoU) para la imagen 169: 0.3194
# Coeficiente de Jaccard (IoU) para la imagen 170: 0.7155
# Coeficiente de Jaccard (IoU) para la imagen 171: 0.1883
# Coeficiente de Jaccard (IoU) para la imagen 172: 0.6529
# Coeficiente de Jaccard (IoU) para la imagen 173: 0.3857
# Coeficiente de Jaccard (IoU) para la imagen 174: 0.2509
# Coeficiente de Jaccard (IoU) para la imagen 175: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 176: 0.2496
# Coeficiente de Jaccard (IoU) para la imagen 177: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 178: 0.6852
# Coeficiente de Jaccard (IoU) para la imagen 179: 0.3177
# Coeficiente de Jaccard (IoU) para la imagen 180: 0.7107
# Coeficiente de Jaccard (IoU) para la imagen 181: 0.4222
# Coeficiente de Jaccard (IoU) para la imagen 182: 0.0182
# Coeficiente de Jaccard (IoU) para la imagen 183: 0.3186
# Coeficiente de Jaccard (IoU) para la imagen 184: 0.3868
# Coeficiente de Jaccard (IoU) para la imagen 185: 0.5640
# Coeficiente de Jaccard (IoU) para la imagen 186: 0.3674
# Coeficiente de Jaccard (IoU) para la imagen 187: 0.3190
# Coeficiente de Jaccard (IoU) para la imagen 188: 0.5734
# Coeficiente de Jaccard (IoU) para la imagen 189: 0.4377
# Coeficiente de Jaccard (IoU) para la imagen 190: 0.4993
# Coeficiente de Jaccard (IoU) para la imagen 191: 0.5748
# Coeficiente de Jaccard (IoU) para la imagen 192: 0.3808
# Coeficiente de Jaccard (IoU) para la imagen 193: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 194: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 195: 0.7634
# Coeficiente de Jaccard (IoU) para la imagen 196: 0.7655
# Coeficiente de Jaccard (IoU) para la imagen 197: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 198: 0.7096
# Coeficiente de Jaccard (IoU) para la imagen 199: 0.1772
# Coeficiente de Jaccard (IoU) para la imagen 200: 0.3132
# Coeficiente de Jaccard (IoU) para la imagen 201: 0.6117
# Coeficiente de Jaccard (IoU) para la imagen 202: 0.0073
# Coeficiente de Jaccard (IoU) para la imagen 203: 0.3649
# Coeficiente de Jaccard (IoU) para la imagen 204: 0.1945
# Coeficiente de Jaccard (IoU) para la imagen 205: 0.7752
# Coeficiente de Jaccard (IoU) para la imagen 206: 0.0248
# Coeficiente de Jaccard (IoU) para la imagen 207: 0.7693
# Coeficiente de Jaccard (IoU) para la imagen 208: 0.1345
# Coeficiente de Jaccard (IoU) para la imagen 209: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 210: 0.2018
# Coeficiente de Jaccard (IoU) para la imagen 211: 0.5320
# Coeficiente de Jaccard (IoU) para la imagen 212: 0.5778
# Coeficiente de Jaccard (IoU) para la imagen 213: 0.0113
# Coeficiente de Jaccard (IoU) para la imagen 214: 0.7257
# Coeficiente de Jaccard (IoU) para la imagen 215: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 216: 0.4362
# Coeficiente de Jaccard (IoU) para la imagen 217: 0.3907
# Coeficiente de Jaccard (IoU) para la imagen 218: 0.1461
# Coeficiente de Jaccard (IoU) para la imagen 219: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 220: 0.7737
# Coeficiente de Jaccard (IoU) para la imagen 221: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 222: 0.8656
# Coeficiente de Jaccard (IoU) para la imagen 223: 0.5496
# Coeficiente de Jaccard (IoU) para la imagen 224: 0.5856
# Coeficiente de Jaccard (IoU) para la imagen 225: 0.1706
# Coeficiente de Jaccard (IoU) para la imagen 226: 0.4632
# Coeficiente de Jaccard (IoU) para la imagen 227: 0.0157
# Coeficiente de Jaccard (IoU) para la imagen 228: 0.6375
# Coeficiente de Jaccard (IoU) para la imagen 229: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 230: 0.2427
# Coeficiente de Jaccard (IoU) para la imagen 231: 0.2225
# Coeficiente de Jaccard (IoU) para la imagen 232: 0.8257
# Coeficiente de Jaccard (IoU) para la imagen 233: 0.6820
# Coeficiente de Jaccard (IoU) para la imagen 234: 0.6950
# Coeficiente de Jaccard (IoU) para la imagen 235: 0.6667
# Coeficiente de Jaccard (IoU) para la imagen 236: 0.4565
# Coeficiente de Jaccard (IoU) para la imagen 237: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 238: 0.1369
# Coeficiente de Jaccard (IoU) para la imagen 239: 0.0377
# Coeficiente de Jaccard (IoU) para la imagen 240: 0.6408
# Coeficiente de Jaccard (IoU) para la imagen 241: 0.4149
# Coeficiente de Jaccard (IoU) para la imagen 242: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 243: 0.5696
# Coeficiente de Jaccard (IoU) para la imagen 244: 0.2891
# Coeficiente de Jaccard (IoU) para la imagen 245: 0.7671
# Coeficiente de Jaccard (IoU) para la imagen 246: 0.5434
# Coeficiente de Jaccard (IoU) para la imagen 247: 0.5439
# Coeficiente de Jaccard (IoU) para la imagen 248: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 249: 0.0445
# Coeficiente de Jaccard (IoU) para la imagen 250: 0.3525
# Coeficiente de Jaccard (IoU) para la imagen 251: 0.3977
# Coeficiente de Jaccard (IoU) para la imagen 252: 0.0685
# Coeficiente de Jaccard (IoU) para la imagen 253: 0.6096
# Coeficiente de Jaccard (IoU) para la imagen 254: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 255: 0.1987
# Coeficiente de Jaccard (IoU) para la imagen 256: 0.0001
# Coeficiente de Jaccard (IoU) para la imagen 257: 0.3778
# Coeficiente de Jaccard (IoU) para la imagen 258: 0.0003
# Coeficiente de Jaccard (IoU) para la imagen 259: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 260: 0.3758
# Coeficiente de Jaccard (IoU) para la imagen 261: 0.7961
# Coeficiente de Jaccard (IoU) para la imagen 262: 0.6457
# Coeficiente de Jaccard (IoU) para la imagen 263: 0.2702
# Coeficiente de Jaccard (IoU) para la imagen 264: 0.3125
# Coeficiente de Jaccard (IoU) para la imagen 265: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 266: 0.5362
# Coeficiente de Jaccard (IoU) para la imagen 267: 0.5549
# Coeficiente de Jaccard (IoU) para la imagen 268: 0.4981
# Coeficiente de Jaccard (IoU) para la imagen 269: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 270: 0.5421
# Coeficiente de Jaccard (IoU) para la imagen 271: 0.4613
# Coeficiente de Jaccard (IoU) para la imagen 272: 0.4492
# Coeficiente de Jaccard (IoU) para la imagen 273: 0.6902
# Coeficiente de Jaccard (IoU) para la imagen 274: 0.3561
# Coeficiente de Jaccard (IoU) para la imagen 275: 0.7418
# Coeficiente de Jaccard (IoU) para la imagen 276: 0.4915
# Coeficiente de Jaccard (IoU) para la imagen 277: 0.3373
# Coeficiente de Jaccard (IoU) para la imagen 278: 0.3803
# Coeficiente de Jaccard (IoU) para la imagen 279: 0.7795
# Coeficiente de Jaccard (IoU) para la imagen 280: 0.3108
# Coeficiente de Jaccard (IoU) para la imagen 281: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 282: 0.8137
# Coeficiente de Jaccard (IoU) para la imagen 283: 0.7096
# Coeficiente de Jaccard (IoU) para la imagen 284: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 285: 0.4583
# Coeficiente de Jaccard (IoU) para la imagen 286: 0.3686
# Coeficiente de Jaccard (IoU) para la imagen 287: 0.6656
# Coeficiente de Jaccard (IoU) para la imagen 288: 0.0574
# Coeficiente de Jaccard (IoU) para la imagen 289: 0.4289
# Coeficiente de Jaccard (IoU) para la imagen 290: 0.0000
# Coeficiente de Jaccard (IoU) para la imagen 291: 0.0022
# Coeficiente de Jaccard (IoU) para la imagen 292: 0.7822
# Coeficiente de Jaccard (IoU) para la imagen 293: 0.0013

# %%
print(jaccard_coefficients)
# Out:
# [0.5888410410035574, 0.31513031132745156, 0.5641054465741105, 0.4097910764872521, 0.3512284344258243, 0.06828430319948464, 0.4428861960850775, 0.0756769825918762, 0.2377754266525599, 0.0, 0.4640352307943239, 0.1775017413512886, 0.09331078322738671, 0.46059379217273955, 0.6885471024443834, 0.04707803734999645, 0.04544098637764741, 0.710204081632653, 0.3228465362109105, 0.0, 0.8096939991150142, 0.4862467335992298, 0.19351642129105323, 0.35002587035257593, 0.3939431143851033, 0.6593206504677591, 0.24108885464817667, 0.0, 0.67315965583174, 0.559178601017872, 0.0, 0.7480669401386721, 0.6810436634717785, 0.4937694704049844, 0.6467677080111351, 0.012848955444629322, 0.08452753102850599, 0.27137970353477764, 0.6770857274189841, 0.11252492640774855, 0.33404478249058944, 0.7010321556173085, 0.0, 0.8310409502969678, 0.6742618741976893, 0.21792295768987888, 0.6644224592059617, 0.5265306122448979, 0.7380635624538063, 0.0007074637424831977, 0.7608601350932639, 0.7972190034762456, 0.29722336205717415, 0.2615801869959318, 0.12363889103405669, 0.3013267156628806, 0.844314131309647, 0.0, 0.42329453604914324, 0.2165545384360869, 0.0, 0.2557403008709422, 0.3303810314604668, 0.3344132833856434, 0.7305454545454545, 0.784898664307083, 0.11918429003021148, 0.14924874791318865, 0.6105047748976807, 0.24605704934683859, 0.0, 0.5288059470342265, 0.0, 0.30760330578512396, 0.7475319926873858, nan, 0.5150585347432024, 0.27932916064837104, 0.6285585855558885, 0.3443250817375058, 0.0, 0.6715344794529303, 0.41377828702377545, 0.5698722313453759, 0.12363723493470707, 0.14820710455764075, 0.15009560229445507, 0.09731487378901144, 0.303943836465001, 0.5843686114168894, 0.11884461458152079, 0.5040653711683877, 0.0, 0.2442528735632184, 0.42228958497062236, 0.7114872616290396, 0.8459201388888888, 0.6271860095389508, 0.0, 0.3723333962620351, 0.2192408776969623, 0.690819357092942, 0.40954476222711117, 0.5188379482523832, 4.2498937526561835e-05, 0.0, 0.5194283769989793, 0.19686800894854586, 0.0, 0.26967615309126597, 0.18702174407152056, 0.0646743295019157, 0.0, 0.37229574955459405, 0.44495055439017084, 0.7259091919117102, 0.37321601773590135, 0.7541989339233631, 0.28611852211173094, 0.3974471061374366, 0.5111123216036605, 0.12830503757305872, 0.0, 0.7227124496451179, 0.7165311653116531, 0.058823529411764705, 0.4555468135326515, 0.6615138592750534, 0.2919623572971305, 0.32180020811654525, 0.35899870850110155, 0.15886017535763727, 0.5708569063060577, 0.5373941250675798, 0.7972271321254971, 0.1575200621278799, 0.8090734977256404, 0.49718748995532125, 0.29526685566374955, 0.6853515020130071, 0.04177578251652326, 0.0, 0.32874583795782464, 0.2053540467438796, 0.0, 0.7384081329035458, 0.3781104199066874, 0.4186987034614012, 0.7356969402622633, 0.0007547169811320754, 0.0, 0.33220825852782765, 0.8271778821074596, 0.5954350642878501, 0.759046131284471, 0.3799119647859144, 0.3396034873999761, 0.5513924488091467, 0.008228400448821843, 0.30454242453099706, 0.8025473017742767, 0.4106037603643583, 0.0, 0.140978784096987, 0.08807414315691303, 0.7385784450004633, 0.062193280483201205, 0.5740776636299024, 0.7026696655583806, 0.31938264738598443, 0.7155479963494565, 0.1882727339234765, 0.6528756031279463, 0.3856942496493689, 0.2508526131440686, 0.0, 0.249630387808484, 0.0, 0.6851698425849213, 0.31767824012721974, 0.7106536028773409, 0.4222222222222222, 0.018203521336914354, 0.31862253426947507, 0.3868022411288649, 0.5640087313816128, 0.3674370164649871, 0.3189943322191542, 0.5733845616486203, 0.4376622128232241, 0.4993024066968957, 0.5747754783287778, 0.380804311774461, 0.0, 0.0, 0.7633693746347165, 0.7655288602402578, 0.0, 0.7095937770095073, 0.17715544367526748, 0.3131752995874533, 0.6117394416607015, 0.007290184921763869, 0.36485440650091905, 0.19452668640473714, 0.7752307692307693, 0.02481121898597627, 0.76930409914204, 0.13454421503700817, 0.0, 0.20176522506619593, 0.5319554573421725, 0.5778494623655914, 0.011309752659233629, 0.7257094757094757, 0.0, 0.43623258049014896, 0.390748528 ...

# %%
import pandas as pd
jaccard_coefficient_series = pd.Series(jaccard_coefficients)
jaccard_coefficient_summary = jaccard_coefficient_series.describe()
print(jaccard_coefficient_summary)
# Out:
# count    293.000000
# mean       0.368456
# std        0.267665
# min        0.000000
# 25%        0.123637
# 50%        0.367437
# 75%        0.588841
# max        0.865554
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crea un DataFrame de Pandas con tus datos
df = pd.DataFrame(jaccard_coefficients, columns=['IOU'])

# Crea un diagrama de caja y bigotes usando el método boxplot de Pandas
df.boxplot(column=['IOU'])

# Mostrar el gráfico
plt.show()

# %%
pd.Series(predicted_mask.ravel()).plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>
